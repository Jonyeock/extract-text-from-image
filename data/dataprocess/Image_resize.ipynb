# %% [markdown]
# <a href="https://colab.research.google.com/github/Jonyeock/extract-text-from-image/blob/master/data/dataprocess/Image_resize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
cd drive/My\ Drive/googleimage
# Out:
# /content/drive/My Drive/googleimage

# %%
img = cv2.imread('tit.jpg')

h, w = img.shape[:2]
img2 = cv2.resize(img, (512, 512), fx=1, fy=1, interpolation=cv2.INTER_AREA)

plt.figure(figsize=(5.12, 5.12))
plt.axis('off'), plt.xticks([]), plt.yticks([])
plt.tight_layout()
plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
plt.imshow(img2, 'gray')
plt.show
plt.savefig("test.jpg",
            bbox_inces='tight', 
            pad_inches=0, 
            dpi=100
           )
